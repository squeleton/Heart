# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import plotly.express as px
import plotly.graph_objects as go


data = pd.read_csv("books_data.csv")
data.tail(60)
# Out:
#        bookID                                              title  \
# 11067   45420                                     The Home Front
# 11068   45431                           Half Moon Investigations
# 11069   45432                                The Supernaturalist
# 11070   45436                                      The Wish List
# 11071   45438               Legend of the Worst Boy in the World
# 11072   45440                          The Legend of Spud Murphy
# 11073   45442             La venganza de Opal (Artemis Fowl  #4)
# 11074   45444                                        Going Potty
# 11075   45449                    Artemis Fowl (Artemis Fowl  #1)
# 11076   45450                              La última oportunidad
# 11077   45455                    Artemis Fowl (Artemis Fowl  #1)
# 11078   45462             La venganza de opal (Artemis Fowl  #4)
# 11079   45463          Encuentro en el Ártico (Artemis Fowl  #2)
# 11080   45465                    Artemis Fowl (Artemis Fowl  #1)
# 11081   45472  Treasury of American Tall Tales: Volume 1: Dav...
# 11082   45479          The Subtle Knife (His Dark Materials  #2)
# 11083   45480        The Amber Spyglass (His Dark Materials  #3)
# 11084   45485          The Subtle Knife (His Dark Materials  #2)
# 11085   45486      His Dark Materials (His Dark Materials  #1-3)
# 11086   45487         El catalejo lacado (La Materia Oscura  #3)
# 11087   45490    His Dark Materials Omnibus (His Dark Materials)
# 11088   45492           Northern Lights (His Dark Materials  #1)
# 11089   45495   El alquimista: una fábula para seguir tus sueños
# 11090   45500                 La conspiración de los alquimistas
# 11091   45503  El Alquimista: Edicion Illustrada: Edicion Ill...
# 11092   45506                  The Call of the Mall: How we shop
# 11093   45511      Die Broke: A Radical Four-Part Financial Plan
# 11094   45515                               Live Rich  Die Broke
# 11095   45516             The Die Broke Financial Problem Solver
# 11096   45529             Montaillou: The Promised Land of Error
# 11097   45530  Montaillou: Cathars and Catholics in a French ...
# 11098   45531         Montaillou  village occitan de 1294 à 1324
# 11099   45533  Montaillou: Cathars and Catholics in a French ...
# 11100   45536                                        On the Road
# 11101   45546  Undaunted Courage: The Pioneering First Missio...
# 11102   45549                                  Undaunted Courage
# 11103   45557   Co. Aytch: A Confederate Memoir of the Civil War
# 11104   45564                             Jonny Reb & Billy Yank
# 11105   45568                                      El Superzorro
# 11106   45570                                   Fantastic Mr Fox
# 11107   45572                 Fantastic Mr. Fox (Cover to Cover)
# 11108   45574                                     Ajax in Action
# 11109   45583                      Historia del rey transparente
# 11110   45585                                     Bella y oscura
# 11111   45592                       La tía Julia y el escribidor
# 11112   45595                       La Tía Julia y el Escribidor
# 11113   45604                        Narraciones Extraordinarias
# 11114   45607                             Las Crónicas de Narnia
# 11115   45615       O Trono de Prata (As Crónicas de Nárnia  #6)
# 11116   45616       A Última Batalha (As Crónicas de Nárnia  #7)
# 11117   45617  O Cavalo e o Seu Rapaz (As Crónicas de Nárnia ...
# 11118   45623   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11119   45625  A Viagem do Caminheiro da Alvorada (As Crónica...
# 11120   45626     O Príncipe Caspian (As Crónicas de Nárnia  #4)
# 11121   45630                                  Whores for Gloria
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating
# 11067         Brian Braithwaite/Noelle Walsh/Glyn Davies           3.40
# 11068                                        Eoin Colfer           3.77
# 11069                                        Eoin Colfer           3.86
# 11070                                        Eoin Colfer           3.77
# 11071                            Eoin Colfer/Glenn McCoy           3.76
# 11072                            Eoin Colfer/Glenn McCoy           3.88
# 11073                            Eoin Colfer/Ana Alcaina           4.05
# 11074                                        Eoin Colfer           3.14
# 11075                       Eoin Colfer/Claudia Feldmann           3.84
# 11076                                        Eoin Colfer           3.77
# 11077                            Eoin Colfer/Ana Alcaina           3.84
# 11078                                        Eoin Colfer           4.05
# 11079                      Eoin Colfer/Ana Alcaina Pérez           3.95
# 11080                       Eoin Colfer/Nathaniel Parker           3.84
# 11081  David Bromberg/Jay Ungar/Molly Mason/Garrison ...           3.86
# 11082                            Philip Pullman/Ian Beck           4.13
# 11083                            Philip Pullman/Ian Beck           4.09
# 11084                                     Philip Pullman           4.13
# 11085                                     Philip Pullman           4.26
# 11086                                     Philip Pullman           4.09
# 11087                                     Philip Pullman           4.26
# 11088                                     Philip Pullman           3.98
# 11089                       Paulo Coelho/Juan Godó Costa           3.86
# 11090                                   Hania Czajkowski           4.00
# 11091                                       Paulo Coelho           3.86
# 11092                                     Paco Underhill           3.60
# 11093                      Stephen M. Pollan/Mark LeVine           3.64
# 11094                                  Stephen M. Pollan           3.29
# 11095                      Stephen M. Pollan/Mark LeVine           2.33
# 11096               Emmanuel Le Roy Ladurie/Barbara Bray           3.96
# 11097               Emmanuel Le Roy Ladurie/Barbara Bray           3.96
# 11098    Emmanuel Le Roy Ladurie/Emmanuel Le Roy-Ladurie           3.96
# 11099               Emmanuel Le Roy Ladurie/Barbara Bray           3.96
# 11100                          Jack Kerouac/Ann Charters           3.63
# 11101                                 Stephen E. Ambrose           4.21
# 11102                Stephen E. Ambrose/Barrett Whitener           4.21
# 11103                                     Sam R. Watkins           4.13
# 11104                                   Alexander Hunter           4.11
# 11105                           Roald Dahl/Horacio Elena           4.05
# 11106                              David Wood/Roald Dahl           4.09
# 11107                                         Roald Dahl           4.05
# 11108            Dave Crane/Eric Pascarello/Darren James           3.56
# 11109                                       Rosa Montero           3.90
# 11110                                       Rosa Montero           3.66
# 11111                                 Mario Vargas Llosa           3.92
# 11112                                 Mario Vargas Llosa           3.92
# 11113                                    Edgar Allan Poe           4.13
# 11114  C.S. Lewis/Margarita E. Valdes/Gemma Gallart/P...           4.26
# 11115                       C.S. Lewis/Ana Falcão Bastos           3.96
# 11116        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos           4.03
# 11117        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos           3.92
# 11118        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos           4.04
# 11119        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos           4.09
# 11120        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos           3.97
# 11121                                William T. Vollmann           3.69
# 11122  William T. Vollmann/Larry McCaffery/Michael He...           4.06
# 11123                                William T. Vollmann           4.08
# 11124                                William T. Vollmann           3.96
# 11125                                William T. Vollmann           3.72
# 11126                                         Mark Twain           3.91

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bookID          11127 non-null  int64
#  1   title           11127 non-null  object
#  2   authors         11127 non-null  object
#  3   average_rating  11127 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 347.8+ KB

# %%
fig = px.histogram(data, x='average_rating',
                   nbins=30,
                   title='Distribution of Average Ratings')
fig.update_xaxes(title_text='Average Rating')
fig.update_yaxes(title_text='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="
41","4.05","4.14","3.68","3.72","3.55","3.62","3.55","3.76","4.05","4.05","4.26","0.00","4.18","4.42","4.07","3.58","3.96","3.90","3.76","4.00","3.78","3.91","4.10","3.92","3.92","4.47","4.50","4.06","4.35","3.85","3.95","3.99","3.99","3.99","3.99","3.99","3.99","3.99","3.99","3.86","3.86","3.86","4.04","3.86","3.86","3.86","3.76","3.76","3.76","3.76","3.76","4.35","4.22","4.13","3.80","3.94","4.50","4.50","4.02","4.44","3.64","3.31","3.70","3.57","3.57","3.62","3.70","4.02","3.69","4.02","4.29","4.32","3.72","4.35","3.90","3.90","4.29","4.50","4.03","4.21","4.21","4.40","4.17","4.00","4.31"," ...

# %%
top_authors = data['authors'].value_counts().head(5)
fig = px.bar(top_authors, x=top_authors.values, y=top_authors.index, orientation='h',
             labels={'x': 'Number of Books', 'y': 'Author'},
             title='Number of Books per Author')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5f51f9db-baaa-491a-ae07-29f013ea2262" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f51f9db-baaa-491a-ae07-29f013ea2262")) {                    Plotly.newPlot(                        "5f51f9db-baaa-491a-ae07-29f013ea2262",                        [{"alignmentgroup":"True","hovertemplate":"Number of Books=%{x}\u003cbr\u003eauthors=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[40,40,39,35,33],"xaxis":"x","y":["Stephen King","P.G. Wodehouse","Rumiko Takahashi","Orson Scott Card","Agatha Christie"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"ty ...

# %%
# Convert 'average_rating' to a numeric data type
data['average_rating'] = pd.to_numeric(data['average_rating'],errors='coerce')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bookID          11127 non-null  int64
#  1   title           11127 non-null  object
#  2   authors         11127 non-null  object
#  3   average_rating  11123 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 347.8+ KB

# %%
# Create a new column 'book_content' by combining 'title' and 'authors'
data['bookContet'] = data['title'] + ' ' + data['authors']
data.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating  \
# 0  J.K. Rowling/Mary GrandPré            4.57
# 1  J.K. Rowling/Mary GrandPré            4.49
# 2                J.K. Rowling            4.42
# 3  J.K. Rowling/Mary GrandPré            4.56
# 4  J.K. Rowling/Mary GrandPré            4.78
#
#                                           bookContet
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['bookContet'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend_books(book_title, cosine_sim=cosine_sim):
    # Get the index of the book that matches the title
    idx = data[data['title'] == book_title].index[0]

    # Get the cosine similarity scores for all books with this book
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the books based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the top 10 most similar books (excluding the input book)
    sim_scores = sim_scores[1:11]

    # Get the book indices
    book_indices = [i[0] for i in sim_scores]

    # Return the top 10 recommended books
    return data['title'].iloc[book_indices]

# %%
book_title = "Las Crónicas de Narnia"
recommended_books = recommend_books(book_title)
print(recommended_books)
# Out:
# 3018     The Chronicles of Narnia (The Chronicles of Na...
# 9495         The Lion  the Witch and the Wardrobe (Narnia)
# 9494     The Lion  the Witch and the Wardrobe (Chronicl...
# 5014     The Voyage of the “Dawn Treader” (The Chronicl...
# 11120       O Príncipe Caspian (As Crónicas de Nárnia  #4)
# 11116         A Última Batalha (As Crónicas de Nárnia  #7)
# 11118     O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 3878                  The Lion  the Witch and the Wardrobe
# 11117    O Cavalo e o Seu Rapaz (As Crónicas de Nárnia ...
# 11119    A Viagem do Caminheiro da Alvorada (As Crónica...
# Name: title, dtype: object
